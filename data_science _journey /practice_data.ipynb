# %% [markdown]
# This is a frist practice code. code with harry data science course.

# %%
import json
# Out:
# Running cells with 'Python 3.11.8' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python -m pip install ipykernel -U --user --force-reinstall'
